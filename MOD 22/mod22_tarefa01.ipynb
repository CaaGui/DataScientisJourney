# %% [markdown]
# # Tarefa 01
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %% [markdown]
# #### 1. Baixando dados de ativos
#     1. Baixe os dados de três ativos da sua escolha do Yahoo Finance, correspondente a um período de pelo menos 2 anos até a data mais recente.
#     2. Salve esses dados para que você possa utilizá-los na próxima tarefa.

# %%
import yfinance as yf

import plotly.express as px
from plotly import graph_objects

import pandas as pd
import numpy as np

# %%
# %%time

assets = ['^BVSP','PETR4.SA','VALE3.SA']

dt_ini  = '2015-01-01' 

df = yf.download(assets, start= dt_ini)
df
# Out:
# [*********************100%***********************]  3 of 3 completed
# Wall time: 905 ms
#             Adj Close                                Close             \
#              PETR4.SA   VALE3.SA          ^BVSP   PETR4.SA   VALE3.SA
# Date
# 2015-01-02   4.124554  13.109157   48512.000000   9.360000  21.280001
# 2015-01-05   3.772028  12.912024   47517.000000   8.560000  20.959999
# 2015-01-06   3.648644  13.429492   48001.000000   8.280000  21.799999
# 2015-01-07   3.820501  13.922317   49463.000000   8.670000  22.600000
# 2015-01-08   4.067269  14.070165   49943.000000   9.230000  22.840000
# ...               ...        ...            ...        ...        ...
# 2023-04-10  24.510000  78.230003  101847.000000  24.510000  78.230003
# 2023-04-11  25.660000  82.360001  106214.000000  25.660000  82.360001
# 2023-04-12  25.850000  80.599998  106890.000000  25.850000  80.599998
# 2023-04-13  26.030001  79.510002  106458.000000  26.030001  79.510002
# ...

# %% [markdown]
# #### 2. Observando a volatilidade dentro do dia
# 1. Calcule a amplitude de variação do valor do ativo dentro do dia. Essa amplitude você pode calcular com um comando simples de adicionar uma coluna no Pandas: (valor máximo - valor mínimo).
# 2. Monte um gráfico de linha mostrando a variação dessa amplitude ao longo do período coletado, por ativo.
# 3. Veja se consegue identificar que ativo apresentou maior volatilidade.

# %%
df_amplitude = df['High'] / df['Low'] - 1
df_amplitude = df_amplitude.stack().reset_index()
df_amplitude.columns = ['data', 'ativo','valor']

# %%
fig = px.line(df_amplitude, x= 'data', y= 'valor', color= 'ativo', template= 'simple_white')
fig.show()
# Out:
# <div>                            <div id="588a7418-b8f2-417e-9fd1-097cce5035fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("588a7418-b8f2-417e-9fd1-097cce5035fd")) {                    Plotly.newPlot(                        "588a7418-b8f2-417e-9fd1-097cce5035fd",                        [{"hovertemplate":"ativo=PETR4.SA<br>data=%{x}<br>valor=%{y}<extra></extra>","legendgroup":"PETR4.SA","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"PETR4.SA","showlegend":true,"x":["2015-01-02T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:0
# ...

# %%
PETR4.SA apresentou a maior oscilação entre os anos de 2018 e 2019
